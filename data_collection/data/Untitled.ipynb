# %%
import pandas as pd

# %%
df = pd.read_csv('BetaCoV.csv')
# Out:
#       Accession          Release_Date  \
# 0     NC_045512  2020-01-13T00:00:00Z
# 1     NC_006213  2019-02-21T00:00:00Z
# 2     NC_038294  2018-08-24T00:00:00Z
# 3     NC_039207  2018-08-24T00:00:00Z
# 4     NC_030886  2016-09-12T00:00:00Z
# ...         ...                   ...
# 9832     X04997  1987-09-19T00:00:00Z
# 9833     X04998  1987-06-07T00:00:00Z
# 9834     X04223  1987-03-09T00:00:00Z
# 9835     X00990  1985-06-13T00:00:00Z
# 9836     X00509  1983-12-06T00:00:00Z
#
#                                                 Species         Family  \
# 0     Severe acute respiratory syndrome-related coro...  Coronaviridae
# 1                                     Betacoronavirus 1  Coronaviridae
# 2     Middle East respiratory syndrome-related coron...  Coronaviridae
# 3                                Hedgehog coronavirus 1  Coronaviridae
# 4                      Rousettus bat coronavirus GCCDC1  Coronaviridae
# ...                                                 ...            ...
# ...

# %%
df.count()
# Out:
# Accession           9837
# Release_Date        9837
# Species             9837
# Family              9837
# Length              9837
# Nuc_Completeness    9837
# Authors             9723
# Publications        4087
# Geo_Location        8352
# Host                7518
# Isolation_Source    3646
# Collection_Date     7497
# GenBank_Title       9837
# dtype: int64

# %%
df_species=df.groupby(['Species']).count()
df_species
# Out:
#                                                     Accession  Release_Date  \
# Species
# Alpaca coronavirus                                         23            23
# Bat Coronavirus Rhhar/CII_KSA_004/Bisha/Saudi A...          1             1
# Bat Coronavirus Taper/CII_KSA_287/Bisha/Saudi A...          1             1
# Bat Hp-betacoronavirus Zhejiang2013                         2             2
# Bat Hp-betacoronavirus/Zhejiang2013-1                       1             1
# ...                                                       ...           ...
# Tylonycteris bat coronavirus HKU4                          86            86
# Tylonycteris pachypus bat coronavirus HKU4-related          1             1
# Vespertilionid betacoronavirus                              3             3
# Zaria bat coronavirus                                       1             1
# coronavirus Mex_CoV-11b                                     3             3
#
# ...

# %%
df_species.to_csv('species.csv')

# %%
## recode the species name
##import species dic
dic=pd.read_csv("species_dic.csv",index_col=0, squeeze=True).to_dict()
df['Species_code']=df['Species'].map(dic)
df_species=df.groupby(['Species_code']).count()
df_species
# Out:
#                                                     Accession  Release_Date  \
# Species_code
# Alpaca coronavirus                                         24            24
# Bat SARS Cov                                                8             8
# Bat betacoronavirus                                       135           135
# Betacoronavirus 1                                        3018          3018
# Betacoronavirus Erinaceus                                  14            14
# Betacoronavirus sp.                                       135           135
# Bovine coronaviurus                                         2             2
# Camel coronavirus HKU23                                     2             2
# China Rattus coronavirus HKU24                              4             4
# Dromedary camel coronavirus                                 1             1
# Eidolon bat coronavirus                                   352           352
# ...

# %%
df_species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, Alpaca coronavirus to Unclassified betacoronavirus
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Accession         30 non-null     int64
#  1   Release_Date      30 non-null     int64
#  2   Species           30 non-null     int64
#  3   Family            30 non-null     int64
#  4   Length            30 non-null     int64
#  5   Nuc_Completeness  30 non-null     int64
#  6   Authors           30 non-null     int64
#  7   Publications      30 non-null     int64
#  8   Geo_Location      30 non-null     int64
#  9   Host              30 non-null     int64
#  10  Isolation_Source  30 non-null     int64
#  11  Collection_Date   30 non-null     int64
#  12  GenBank_Title     30 non-null     int64
# dtypes: int64(13)
# memory usage: 3.3+ KB

# %%
## filter the dataframe by length

df2 = df.loc[df['Length'] > 20000]
df2
df2.to_csv("BetaCoV_WGS.csv",index=False)

# %%
df2_species=df2.groupby(['Species_code']).count()
df2_species
# Out:
#                                                     Accession  Release_Date  \
# Species_code
# Bat SARS Cov                                                1             1
# Bat betacoronavirus                                         4             4
# Betacoronavirus 1                                         323           323
# Betacoronavirus sp.                                        11            11
# Camel coronavirus HKU23                                     2             2
# China Rattus coronavirus HKU24                              4             4
# Erinaceus hedgehog coronavirus HKU31                        2             2
# Hedgehog coronavirus 1                                      4             4
# Human coronavirus HKU1                                     48            48
# Hypsugo bat coronavirus HKU25                               2             2
# Longquan Aa mouse coronavirus                               1             1
# ...

# %%
df2_species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, Bat SARS Cov to Unclassified betacoronavirus
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Accession         22 non-null     int64
#  1   Release_Date      22 non-null     int64
#  2   Species           22 non-null     int64
#  3   Family            22 non-null     int64
#  4   Length            22 non-null     int64
#  5   Nuc_Completeness  22 non-null     int64
#  6   Authors           22 non-null     int64
#  7   Publications      22 non-null     int64
#  8   Geo_Location      22 non-null     int64
#  9   Host              22 non-null     int64
#  10  Isolation_Source  22 non-null     int64
#  11  Collection_Date   22 non-null     int64
#  12  GenBank_Title     22 non-null     int64
# dtypes: int64(13)
# memory usage: 2.4+ KB

# %% [markdown]
# ## Data filter:
# Date Guessing: for sequence without month and day information, the mid of the month and the mid of the year were used
#
# Filter CoV19: CoV19 collected after Feb29 were removed

# %%
## parse seq data
from Bio import SeqIO

# %%
BetaCoV_sesq = SeqIO.parse("RSVA_WGS_n.fasta", "fasta")
SeqIO.write(records, "RSVA_WGS_n.tab", "tab")
df = pd.read_csv("RSVA_WGS_n.tab",sep='\t',names=["taxa", "seq"])
df.head
